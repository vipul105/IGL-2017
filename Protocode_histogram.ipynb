# %%
import numpy as np
# %matplotlib notebook
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import pandas as pd

# %%
fname='avespeed.csv'
data = pd.read_csv(fname,usecols=[1]).values.flatten()
print(data)
# Out:
# [ 5.00540774  4.92585373  4.90790527  4.65379934  4.58279562  4.28502625
#   4.2256022   4.21170534  4.18828191  4.13359837  4.1004598   4.06788208
#   3.99939766  3.98517254  3.98380923  3.97971889  3.92377545  3.90749992
#   3.90433337  3.9000917   3.87127385  3.84027267  3.82894782  3.80756805
#   3.78029341  3.77375262  3.76920686  3.75286207  3.70930015  3.69824653
#   3.69438238  3.6684689   3.65410746  3.6323717   3.6027683   3.58834147
#   3.57391226  3.5384723   3.53446791  3.50577582  3.50547731  3.4738309
#   3.46029044  3.44284336  3.43565936  3.43254036  3.42858462  3.41002133
#   3.39171178  3.38643814  3.38562139  3.36334465  3.33041267  3.32325125
#   3.31141296  3.30705766  3.27797062  3.27426658  3.25408731  3.24439716
#   3.20534081  3.18213002  3.16811804  3.1678821   3.1529491   3.14065095
#   3.13856387  3.11644887  3.11088875  3.05423627  3.03620222  3.03070941
#   3.00888288  3.00606266  2.86888007  2.81349285  2.79635852  2.78447736
#   2.77701499  2.77198357  2.73117515  2.73116527  2.73076381  2.71733454
#   2.71564947  2.70866778  2.69477341  2.69124266  2.64236795  2.62642932
#   2.62601139  2.58990681  2.58403188  2.57255863  2.54599062  2.54533209
#   2.52256863  2.48350139  2.47440089  2.45523537  2.45433506  2.45060026
#   2.42160587  2.41322273  2.40980132  2.38504508  2.36171592  2.35965094
#   2.34005607  2.33107445  2.33024685  2.32344039  2.31749309  2.3142282
#   2.29387923  2.2879769   2.27614056  2.25579791  2.25429413  2.24846073
#   2.207002    2.19603914  2.0790175   2.06880592  2.04538963  2.04293236
#   2.02708972  2.01766551  2.00182123  1.99832684  1.97105844  1.95081442
#   1.92158391  1.87586225  1.8721416   1.82872202  1.80872445  1.80389289
#   1.79321663  1.74147262  1.72180975  1.65341058  1.60179034  1.50186292]

# %%
bins=np.arange(start=1,stop=6.5,step=0.5)
# the histogram of the data
n, bins, patches = plt.hist(data,bins=bins, facecolor='green', alpha=0.75)


# add a 'best fit' line
#y = mlab.normpdf( bins, mu, sigma)
#l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('Speed (meters/sec)')
plt.ylabel('Frequency')
#plt.title(r'$\mathrm{Histogram\ of\ IQ:}\ \mu=100,\ \sigma=15$')
#plt.axis([40, 160, 0, 0.03])
#plt.grid(True)

plt.show()
# Out:
# <img src="data:image/png;base64,...">
